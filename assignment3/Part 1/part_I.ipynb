# %% [markdown]
# # Part I
# Name: Zhangjie Chen
# SID: 12012524

# %%
import matplotlib.pyplot as plt

t5_file_path = 'job.15867.out'
t20_file_path = 'job.15865.out'



def plot_result(path):
    train_acc = []
    test_acc = []
    train_loss = []
    test_loss = []

    epochs = list(range(0, 100))
    
    with open(path, 'r') as f:
        for line in f:
            if line.startswith('['):
                parts = line.strip().split()
                train_acc_value = float(parts[3].strip(','))
                test_acc_value = float(parts[6].strip(','))
                train_loss_value = float(parts[9].strip(','))
                test_loss_value = float(parts[12])

                train_acc.append(train_acc_value)
                test_acc.append(test_acc_value)
                train_loss.append(train_loss_value)
                test_loss.append(test_loss_value)

    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_acc, label='Train Accuracy')
    plt.plot(epochs, test_acc, label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Test Accuracy')
    plt.ylim(0, 1)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_loss, label='Train Loss')
    plt.plot(epochs, test_loss, label='Test Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Test Loss')
    plt.legend()


    plt.tight_layout()
    plt.show()

# %% [markdown]
# When T=5:

# %%
plot_result(t5_file_path)

# %% [markdown]
# When T=20:

# %%
plot_result(t20_file_path)
