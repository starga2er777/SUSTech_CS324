# %% [markdown]
# # Part II
# Name: Zhangjie Chen
# SID: 12012524

# %% [markdown]
# ### Task 2

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

def show_gan_res(image_path):
    image = Image.open(image_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %% [markdown]
# Results from the beginning of training process:

# %%
show_gan_res('../pics/0.png')
show_gan_res('../pics/500.png')
show_gan_res('../pics/1000.png')

# %% [markdown]
# Results in the middle of training process:

# %%
show_gan_res('../pics/59500.png')
show_gan_res('../pics/60000.png')
show_gan_res('../pics/59500.png')

# %% [markdown]
# Results after the training process:

# %%
show_gan_res('../pics/186500.png')
show_gan_res('../pics/187000.png')
show_gan_res('../pics/187500.png')

# %% [markdown]
# ### Task 3

# %%
import torch
import torch.nn as nn

mnist_generator = torch.load('mnist_generator.pth')

print(mnist_generator)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 4
#       1 import torch
#       2 import torch.nn as nn
# ----> 4 mnist_generator = torch.load('mnist_generator.pth')
#       6 print(mnist_generator)
#
# File ~/Apps/conda/envs/ml/lib/python3.9/site-packages/torch/serialization.py:1026, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1024             except RuntimeError as e:
#    1025                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1026         return _load(opened_zipfile,
#    1027                      map_location,
#    1028                      pickle_module,
#    1029                      overall_storage=overall_storage,
#    1030                      **pickle_load_args)
#    1031 if mmap:
#    1032     raise RuntimeError("mmap can only be used with files saved with "
# ...
